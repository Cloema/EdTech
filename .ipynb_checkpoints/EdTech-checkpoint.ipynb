# %% [markdown]
# # “I’d like to start an EdTech company in France. Based on data, could you give me some business model advices to raise funds?”

# %%
import pandas as pd

# %%
df = pd.read_csv('datas/input.csv', sep=';', parse_dates=True, squeeze=True)

# %%
df.head(10)
# Out:
#    ID           Nom startup  \
# 0   2          1to1PROGRESS
# 1   3           360Learning
# 2   4            3W Academy
# 3   6              Academyk
# 4   7            Adways SAS
# 5   8           AGT DiGiTAL
# 6   9               aimaira
# 7  10       albert académie
# 8  11                Alcuin
# 9  12  ALTERNATIVE DIGITALE
#
#                                       description fr  \
# 0  Organisme de formation linguistique à distance...
# 1  Créez et diffusez rapidement vos cours, en lig...
# 2                 formation au métier de développeur
# 3  La mission d’Academyk est de développer les co...
# 4  Adways a développé, entre autres, une platefor...
# 5  AGT DiGiTAL a élaboré la première application ...
# 6  aimaira est un ERP conçu pour l’enseignement s...
# 7  albert académie propose du contenu e-learning ...
# 8  Nous sommes éditeurs de solutions logicielles ...
# 9  Alternative Digitale a mis au point DiGiTT, le...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 65 columns):
# ID                         437 non-null int64
# Nom startup                437 non-null object
# description fr             437 non-null object
# description en             437 non-null object
# web                        437 non-null object
# creation                   437 non-null object
# Dirigeants                 434 non-null object
# Nbr employes               437 non-null object
# employeesref               301 non-null float64
# Code postal                437 non-null int64
# Région                     415 non-null object
# Logo                       416 non-null object
# A levé des fonds           437 non-null int64
# Souhaite levé des fonds    437 non-null int64
# Récompensé                 437 non-null int64
# enregistré le              437 non-null object
# Id video youtube           94 non-null object
# internationale             144 non-null float64
# ...

# %%
df.describe()
# Out:
#                ID  employeesref   Code postal  A levé des fonds  \
# count  437.000000    301.000000    437.000000        437.000000
# mean   245.789474      1.976744  68278.123570          0.501144
# std    150.152175      1.330210  21514.502425          0.500572
# min      2.000000      1.000000   2491.000000          0.000000
# 25%    119.000000      1.000000  64000.000000          0.000000
# 50%    232.000000      1.000000  75008.000000          1.000000
# 75%    377.000000      3.000000  75019.000000          1.000000
# max    520.000000      7.000000  97200.000000          1.000000
#
#        Souhaite levé des fonds  Récompensé  internationale
# count               437.000000  437.000000      144.000000
# mean                  0.304348    0.530892        0.381944
# std                   0.460658    0.499617        0.487559
# min                   0.000000    0.000000        0.000000
# 25%                   0.000000    0.000000        0.000000
# ...
